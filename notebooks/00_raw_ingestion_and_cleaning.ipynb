# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls -lh /content/drive/MyDrive/dld_transactions
# Out:
# total 968M
# -rw------- 1 root root 968M Jan 28 10:27 dld_transactions.csv

# %%
# !apt-get update -qq
# !apt-get install openjdk-11-jdk-headless -qq
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !rm -f spark-3.5.0-bin-hadoop3.tgz
# !wget -O spark-3.5.0-bin-hadoop3.tgz https://archive.apache.org/dist/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz
# !ls -lh spark-3.5.0-bin-hadoop3.tgz
# Out:
# --2026-01-28 10:57:56--  https://archive.apache.org/dist/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 400395283 (382M) [application/x-gzip]
# Saving to: ‘spark-3.5.0-bin-hadoop3.tgz’
#
# spark-3.5.0-bin-had 100%[===================>] 381.85M  17.5MB/s    in 25s
#
# 2026-01-28 10:58:22 (15.0 MB/s) - ‘spark-3.5.0-bin-hadoop3.tgz’ saved [400395283/400395283]
#
# -rw-r--r-- 1 root root 382M Sep  9  2023 spark-3.5.0-bin-hadoop3.tgz

# %%
# !tar -xzf spark-3.5.0-bin-hadoop3.tgz
# !ls -lh
# Out:
# total 382M
# drwx------  5 root root 4.0K Jan 28 10:47 drive
# drwxr-xr-x  1 root root 4.0K Jan 16 14:24 sample_data
# drwxr-xr-x 13 1000 1000 4.0K Sep  9  2023 spark-3.5.0-bin-hadoop3
# -rw-r--r--  1 root root 382M Sep  9  2023 spark-3.5.0-bin-hadoop3.tgz

# %% [markdown]
# Colab already has a Google package (dataproc-spark-connect) that prefers PySpark 4.x, but you’re installing PySpark 3.5.0
# run this to execute that----

# %%
# !pip -q uninstall -y dataproc-spark-connect
# !pip -q install pyspark==3.5.0 //

# %%
import os, sys

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"
os.environ["PATH"] += ":/content/spark-3.5.0-bin-hadoop3/bin"

sys.path.insert(0, "/content/spark-3.5.0-bin-hadoop3/python")
sys.path.insert(0, "/content/spark-3.5.0-bin-hadoop3/python/lib/py4j-0.10.9.7-src.zip")

from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("DLD Ingestion").getOrCreate()
spark.range(5).show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %%
csv_path = "/content/drive/MyDrive/dld_transactions/dld_transactions.csv"
csv_path
# Out:
# '/content/drive/MyDrive/dld_transactions/dld_transactions.csv'

# %%
# Print the CSV header

# !head -n 1 "$csv_path"
# Out:
# "transaction_id","procedure_id","trans_group_id","trans_group_ar","trans_group_en","procedure_name_ar","procedure_name_en","instance_date","property_type_id","property_type_ar","property_type_en","property_sub_type_id","property_sub_type_ar","property_sub_type_en","property_usage_ar","property_usage_en","reg_type_id","reg_type_ar","reg_type_en","area_id","area_name_ar","area_name_en","building_name_ar","building_name_en","project_number","project_name_ar","project_name_en","master_project_en","master_project_ar","nearest_landmark_ar","nearest_landmark_en","nearest_metro_ar","nearest_metro_en","nearest_mall_ar","nearest_mall_en","rooms_ar","rooms_en","has_parking","procedure_area","actual_worth","meter_sale_price","rent_value","meter_rent_price","no_of_parties_role_1","no_of_parties_role_2","no_of_parties_role_3"

# %%
# Define an explicit schema
# load everything as strings first to avoid failures


from pyspark.sql.types import StructType, StructField, StringType

header_cols = open(csv_path, "r", encoding="utf-8", errors="ignore") \
    .readline() \
    .strip() \
    .split(",")

schema = StructType([StructField(col, StringType(), True) for col in header_cols])

schema
# Out:
# StructType([StructField('"transaction_id"', StringType(), True), StructField('"procedure_id"', StringType(), True), StructField('"trans_group_id"', StringType(), True), StructField('"trans_group_ar"', StringType(), True), StructField('"trans_group_en"', StringType(), True), StructField('"procedure_name_ar"', StringType(), True), StructField('"procedure_name_en"', StringType(), True), StructField('"instance_date"', StringType(), True), StructField('"property_type_id"', StringType(), True), StructField('"property_type_ar"', StringType(), True), StructField('"property_type_en"', StringType(), True), StructField('"property_sub_type_id"', StringType(), True), StructField('"property_sub_type_ar"', StringType(), True), StructField('"property_sub_type_en"', StringType(), True), StructField('"property_usage_ar"', StringType(), True), StructField('"property_usage_en"', StringType(), True), StructField('"reg_type_id"', StringType(), True), StructField('"reg_type_ar"', StringType(), True), StructField('"reg_type_en"', StringType(), True), StructField('"area_id"', StringType(), True), StructField('"area_name_ar"', StringType(), True), StructField('"area_name_en"', StringType(), True), StructField('"building_name_ar"', StringType(), True), StructField('"building_name_en"', StringType(), True), StructField('"project_number"', StringType(), True), StructField('"project_name_ar"', StringType(), True), StructField('"project_name_en"', StringType(), True), StructField('"master_project_en"', StringType(), True), StructField('"master_project_ar"', StringType(), True), StructField('"nearest_landmark_ar"', StringType(), True), StructField('"nearest_landmark_en"', StringType(), True), StructField('"nearest_metro_ar"', StringType(), True), StructField('"nearest_metro_en"', StringType(), True), StructField('"nearest_mall_ar"', StringType(), True), StructField('"nearest_mall_en"', StringType(), True), StructField('"rooms_ar"', StringType(), True), StructField('"rooms_en"', StringType(), True), StructField('"has_parking"', StringType(), True), StructField('"procedure_area"', StringType(), True), StructField('"actual_worth"', StringType(), True), StructField('"meter_sale_price"', StringType(), True), StructField('"rent_value"', StringType(), True), StructField('"meter_rent_price"', StringType(), True), StructField('"no_of_parties_role_1"', StringType(), True), StructField('"no_of_parties_role_2"', StringType(), True), StructField('"no_of_parties_role_3"', StringType(), True)])

# %%
#Load the CSV using Spark

df_raw = spark.read.csv(
    csv_path,
    header=True,
    schema=schema,
    mode="DROPMALFORMED"
)

# %%
#Validate ingestion

df_raw.printSchema()
print("Row count:", df_raw.count())
df_raw.show(5)
print("Partitions:", df_raw.rdd.getNumPartitions())
# Out:
# root
#  |-- "transaction_id": string (nullable = true)
#  |-- "procedure_id": string (nullable = true)
#  |-- "trans_group_id": string (nullable = true)
#  |-- "trans_group_ar": string (nullable = true)
#  |-- "trans_group_en": string (nullable = true)
#  |-- "procedure_name_ar": string (nullable = true)
#  |-- "procedure_name_en": string (nullable = true)
#  |-- "instance_date": string (nullable = true)
#  |-- "property_type_id": string (nullable = true)
#  |-- "property_type_ar": string (nullable = true)
#  |-- "property_type_en": string (nullable = true)
#  |-- "property_sub_type_id": string (nullable = true)
#  |-- "property_sub_type_ar": string (nullable = true)
#  |-- "property_sub_type_en": string (nullable = true)
#  |-- "property_usage_ar": string (nullable = true)
#  |-- "property_usage_en": string (nullable = true)
#  |-- "reg_type_id": string (nullable = true)
#  |-- "reg_type_ar": string (nullable = true)
#  |-- "reg_type_en": string (nullable = true)
#  |-- "area_id": string (nullable = true)
#  |-- "area_name_ar": string (nullable = true)
#  |-- "area_name_en": string (nullable = true)
#  |-- "building_name_ar": string (nullable = true)
#  |-- "building_name_en": string (nullable = true)
#  |-- "project_number": string (nullable = true)
#  |-- "project_name_ar": string (nullable = true)
#  |-- "project_name_en": string (nullable = true)
#  |-- "master_project_en": string (nullable = true)
#  |-- "master_project_ar": string (nullable = true)
#  |-- "nearest_landmark_ar": string (nullable = true)
#  |-- "nearest_landmark_en": string (nullable = true)
#  |-- "nearest_metro_ar": string (nullable = true)
#  |-- "nearest_metro_en": string (nullable = true)
#  |-- "nearest_mall_ar": string (nullable = true)
#  |-- "nearest_mall_en": string (nullable = true)
#  |-- "rooms_ar": string (nullable = true)
#  |-- "rooms_en": string (nullable = true)
#  |-- "has_parking": string (nullable = true)
#  |-- "procedure_area": string (nullable = true)
#  |-- "actual_worth": string (nullable = true)
#  |-- "meter_sale_price": string (nullable = true)
#  |-- "rent_value": string (nullable = true)
#  |-- "meter_rent_price": string (nullable = true)
#  |-- "no_of_parties_role_1": string (nullable = true)
#  |-- "no_of_parties_role_2": string (nullable = true)
#  |-- "no_of_parties_role_3": string (nullable = true)
#
# Row count: 1647607
# +----------------+--------------+----------------+----------------+----------------+-------------------+--------------------+---------------+------------------+------------------+------------------+----------------------+----------------------+----------------------+-------------------+--------------------+-------------+----------------+-------------------+---------+--------------+--------------+------------------+------------------+----------------+-----------------+-----------------+-------------------+-------------------+---------------------+---------------------+--------------------+--------------------+-----------------+-----------------+----------+----------+-------------+----------------+--------------+------------------+------------+------------------+----------------------+----------------------+----------------------+
# |"transaction_id"|"procedure_id"|"trans_group_id"|"trans_group_ar"|"trans_group_en"|"procedure_name_ar"| "procedure_name_en"|"instance_date"|"property_type_id"|"property_type_ar"|"property_type_en"|"property_sub_type_id"|"property_sub_type_ar"|"property_sub_type_en"|"property_usage_ar"| "property_usage_en"|"reg_type_id"|   "reg_type_ar"|      "reg_type_en"|"area_id"|"area_name_ar"|"area_name_en"|"building_name_ar"|"building_name_en"|"project_number"|"project_name_ar"|"project_name_en"|"master_project_en"|"master_project_ar"|"nearest_landmark_ar"|"nearest_landmark_en"|  "nearest_metro_ar"|  "nearest_metro_en"|"nearest_mall_ar"|"nearest_mall_en"|"rooms_ar"|"rooms_en"|"has_parking"|"procedure_area"|"actual_worth"|"meter_sale_price"|"rent_value"|"meter_rent_price"|"no_of_parties_role_1"|"no_of_parties_role_2"|"no_of_parties_role_3"|
# +----------------+--------------+----------------+----------------+----------------+-------------------+--------------------+---------------+------------------+------------------+------------------+----------------------+----------------------+----------------------+-------------------+--------------------+-------------+----------------+-------------------+---------+--------------+--------------+------------------+------------------+----------------+-----------------+-----------------+-------------------+-------------------+---------------------+---------------------+--------------------+--------------------+-----------------+-----------------+----------+----------+-------------+----------------+--------------+------------------+------------+------------------+----------------------+----------------------+----------------------+
# |    3-9-2006-163|             9|               3|            هبات|           Gifts|                هبه|               Grant|     16-10-2006|                 4|              فيلا|             Villa|                  null|                  NULL|                  NULL|               سكني|         Residential|            1|العقارات القائمة|Existing Properties|      278|         منخول|      Mankhool|              NULL|              NULL|            null|             NULL|             NULL|               NULL|               NULL|            برج خليفة|         Burj Khalifa|محطة مترو بنك أبو...|  ADCB Metro Station|          مول دبي|       Dubai Mall|      NULL|      NULL|            0|         3162.42|   12000000.00|           3794.56|        null|              null|                     3|                     1|                     0|
# |   3-9-2019-2944|             9|               3|            هبات|           Gifts|                هبه|               Grant|     13-11-2019|                 1|               أرض|              Land|                  null|                  NULL|                  NULL|               سكني|         Residential|            1|العقارات القائمة|Existing Properties|      278|         منخول|      Mankhool|              NULL|              NULL|            null|             NULL|             NULL|               NULL|               NULL|            برج خليفة|         Burj Khalifa|محطة مترو بنك أبو...|  ADCB Metro Station|          مول دبي|       Dubai Mall|      NULL|      NULL|            0|          209.09|     916659.00|           4384.04|        null|              null|                     2|                     4|                     0|
# |   2-13-2001-690|            13|               2|            رهون|       Mortgages|          تسجيل رهن|Mortgage Registra...|     20-08-2001|                 2|              مبنى|          Building|                  null|                  NULL|                  NULL|       سكني / تجاري|Residential / Com...|            1|العقارات القائمة|Existing Properties|      388|      عود ميثا|     Oud Metha|              NULL|              NULL|            null|             NULL|             NULL|               NULL|               NULL|            برج خليفة|         Burj Khalifa| محطة مترو عود ميثاء|Oud Metha Metro S...|          مول دبي|       Dubai Mall|      NULL|      NULL|            0|         1337.80|    4519342.00|           3378.19|        null|              null|                     1|                     1|                     0|
# |  2-13-2020-9477|            13|               2|            رهون|       Mortgages|          تسجيل رهن|Mortgage Registra...|     30-11-2020|                 2|              مبنى|          Building|                  null|                  NULL|                  NULL|               سكني|         Residential|            1|العقارات القائمة|Existing Properties|      276|         البدع|       Al Bada|              NULL|              NULL|            null|             NULL|             NULL|               NULL|               NULL|            برج خليفة|         Burj Khalifa|محطة مترو المركز ...|Trade Centre Metr...|          مول دبي|       Dubai Mall|      NULL|      NULL|            0|          278.71|    2500000.00|           8969.90|        null|              null|                     1|                     1|                     0|
# |   2-13-1999-532|            13|               2|            رهون|       Mortgages|          تسجيل رهن|Mortgage Registra...|     26-04-1999|                 4|              فيلا|             Villa|                  null|                  NULL|                  NULL|               سكني|         Residential|            1|العقارات القائمة|Existing Properties|      276|         البدع|       Al Bada|              NULL|              NULL|            null|             NULL|             NULL|               NULL|               NULL|            برج خليفة|         Burj Khalifa|محطة مترو المركز ...|Trade Centre Metr...|          مول دبي|       Dubai Mall|      NULL|      NULL|            0|         3626.93|    1900000.00|            523.86|        null|              null|                     1|                     1|                     0|
# +----------------+--------------+----------------+----------------+----------------+-------------------+--------------------+---------------+------------------+------------------+------------------+----------------------+----------------------+----------------------+-------------------+--------------------+-------------+----------------+-------------------+---------+--------------+--------------+------------------+------------------+----------------+-----------------+-----------------+-------------------+-------------------+---------------------+---------------------+--------------------+--------------------+-----------------+-----------------+----------+----------+-------------+----------------+--------------+------------------+------------+------------------+----------------------+----------------------+----------------------+
# only showing top 5 rows
#
# Partitions: 8

# %%
#Basic casting for key columns
#convert important fields to correct types

from pyspark.sql.functions import col, to_date

df = df_raw

if "transaction_value" in df.columns:
    df = df.withColumn("transaction_value", col("transaction_value").cast("double"))

if "area_sqm" in df.columns:
    df = df.withColumn("area_sqm", col("area_sqm").cast("double"))

if "transaction_date" in df.columns:
    df = df.withColumn("transaction_date", to_date(col("transaction_date")))

# %%
#cleaning

if "transaction_value" in df.columns:
    df = df.dropna(subset=["transaction_value"]) \
           .filter(col("transaction_value") > 0)

# %%
#Show partitioning evidence

df.rdd.getNumPartitions()
df = df.repartition(200)
df.rdd.getNumPartitions()
# Out:
# 200

# %%
out_path = "/content/drive/MyDrive/dld_transactions/cleaned_parquet"
df.write.mode("overwrite").parquet(out_path)

print("Parquet saved to:", out_path)
# Out:
# Parquet saved to: /content/drive/MyDrive/dld_transactions/cleaned_parquet

# %%
#Build the correct explicit schema (recommended)

#This cell defines a proper StructType (IDs as integers/strings, numerics as doubles, date as timestamp-ready)

from pyspark.sql.types import (
    StructType, StructField,
    StringType, IntegerType, DoubleType
)

schema = StructType([
    StructField("transaction_id", StringType(), True),

    StructField("procedure_id", IntegerType(), True),
    StructField("trans_group_id", IntegerType(), True),
    StructField("trans_group_ar", StringType(), True),
    StructField("trans_group_en", StringType(), True),

    StructField("procedure_name_ar", StringType(), True),
    StructField("procedure_name_en", StringType(), True),

    StructField("instance_date", StringType(), True),  # parse after load

    StructField("property_type_id", IntegerType(), True),
    StructField("property_type_ar", StringType(), True),
    StructField("property_type_en", StringType(), True),

    StructField("property_sub_type_id", IntegerType(), True),
    StructField("property_sub_type_ar", StringType(), True),
    StructField("property_sub_type_en", StringType(), True),

    StructField("property_usage_ar", StringType(), True),
    StructField("property_usage_en", StringType(), True),

    StructField("reg_type_id", IntegerType(), True),
    StructField("reg_type_ar", StringType(), True),
    StructField("reg_type_en", StringType(), True),

    StructField("area_id", IntegerType(), True),
    StructField("area_name_ar", StringType(), True),
    StructField("area_name_en", StringType(), True),

    StructField("building_name_ar", StringType(), True),
    StructField("building_name_en", StringType(), True),

    StructField("project_number", StringType(), True),
    StructField("project_name_ar", StringType(), True),
    StructField("project_name_en", StringType(), True),

    StructField("master_project_en", StringType(), True),
    StructField("master_project_ar", StringType(), True),

    StructField("nearest_landmark_ar", StringType(), True),
    StructField("nearest_landmark_en", StringType(), True),

    StructField("nearest_metro_ar", StringType(), True),
    StructField("nearest_metro_en", StringType(), True),

    StructField("nearest_mall_ar", StringType(), True),
    StructField("nearest_mall_en", StringType(), True),

    StructField("rooms_ar", StringType(), True),
    StructField("rooms_en", StringType(), True),

    StructField("has_parking", IntegerType(), True),

    StructField("procedure_area", DoubleType(), True),
    StructField("actual_worth", DoubleType(), True),
    StructField("meter_sale_price", DoubleType(), True),
    StructField("rent_value", DoubleType(), True),
    StructField("meter_rent_price", DoubleType(), True),

    StructField("no_of_parties_role_1", IntegerType(), True),
    StructField("no_of_parties_role_2", IntegerType(), True),
    StructField("no_of_parties_role_3", IntegerType(), True),
])

# %%
#Reload the CSV using this schema (clean, official ingestion)

csv_path = "/content/drive/MyDrive/dld_transactions/dld_transactions.csv"

df = spark.read.csv(
    csv_path,
    header=True,
    schema=schema,
    mode="DROPMALFORMED"
)

# %%
#Parse the date + create time features
# parse instance_date and create year/month/day-of-week

from pyspark.sql.functions import col, to_timestamp, year, month, dayofweek

df = df.withColumn("instance_ts", to_timestamp(col("instance_date")))
df = df.withColumn("year", year(col("instance_ts"))) \
       .withColumn("month", month(col("instance_ts"))) \
       .withColumn("dow", dayofweek(col("instance_ts")))

# %%
#Missing value & sanity cleaning

from pyspark.sql.functions import col

# Drop rows missing key numeric targets (pick one later; for now keep both)
df = df.dropna(subset=["actual_worth", "procedure_area"])

# Filter impossible values
df = df.filter(col("procedure_area") > 0)
df = df.filter(col("actual_worth") > 0)

# Optional: ensure parking is 0/1-ish (some datasets use null/1)
df = df.fillna({"has_parking": 0})

# %%
#Partitioning evidence

print("Before repartition:", df.rdd.getNumPartitions())
df = df.repartition(200)
print("After repartition:", df.rdd.getNumPartitions())
# Out:
# Before repartition: 8
# After repartition: 200

# %%
#Save the handoff dataset as Parquet

out_path = "/content/drive/MyDrive/dld_transactions/cleaned_parquet"
df.write.mode("overwrite").parquet(out_path)
print("Saved Parquet to:", out_path)
# Out:
# Saved Parquet to: /content/drive/MyDrive/dld_transactions/cleaned_parquet

# %%
#screenshots for ingestion

df.printSchema()
print("Row count:", df.count())
df.show(5, truncate=False)
print("Partitions:", df.rdd.getNumPartitions())
# Out:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- procedure_id: integer (nullable = true)
#  |-- trans_group_id: integer (nullable = true)
#  |-- trans_group_ar: string (nullable = true)
#  |-- trans_group_en: string (nullable = true)
#  |-- procedure_name_ar: string (nullable = true)
#  |-- procedure_name_en: string (nullable = true)
#  |-- instance_date: string (nullable = true)
#  |-- property_type_id: integer (nullable = true)
#  |-- property_type_ar: string (nullable = true)
#  |-- property_type_en: string (nullable = true)
#  |-- property_sub_type_id: integer (nullable = true)
#  |-- property_sub_type_ar: string (nullable = true)
#  |-- property_sub_type_en: string (nullable = true)
#  |-- property_usage_ar: string (nullable = true)
#  |-- property_usage_en: string (nullable = true)
#  |-- reg_type_id: integer (nullable = true)
#  |-- reg_type_ar: string (nullable = true)
#  |-- reg_type_en: string (nullable = true)
#  |-- area_id: integer (nullable = true)
#  |-- area_name_ar: string (nullable = true)
#  |-- area_name_en: string (nullable = true)
#  |-- building_name_ar: string (nullable = true)
#  |-- building_name_en: string (nullable = true)
#  |-- project_number: string (nullable = true)
#  |-- project_name_ar: string (nullable = true)
#  |-- project_name_en: string (nullable = true)
#  |-- master_project_en: string (nullable = true)
#  |-- master_project_ar: string (nullable = true)
#  |-- nearest_landmark_ar: string (nullable = true)
#  |-- nearest_landmark_en: string (nullable = true)
#  |-- nearest_metro_ar: string (nullable = true)
#  |-- nearest_metro_en: string (nullable = true)
#  |-- nearest_mall_ar: string (nullable = true)
#  |-- nearest_mall_en: string (nullable = true)
#  |-- rooms_ar: string (nullable = true)
#  |-- rooms_en: string (nullable = true)
#  |-- has_parking: integer (nullable = false)
#  |-- procedure_area: double (nullable = true)
#  |-- actual_worth: double (nullable = true)
#  |-- meter_sale_price: double (nullable = true)
#  |-- rent_value: double (nullable = true)
#  |-- meter_rent_price: double (nullable = true)
#  |-- no_of_parties_role_1: integer (nullable = true)
#  |-- no_of_parties_role_2: integer (nullable = true)
#  |-- no_of_parties_role_3: integer (nullable = true)
#  |-- instance_ts: timestamp (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- dow: integer (nullable = true)
#
# Row count: 1647607
# +-----------------+------------+--------------+--------------+--------------+--------------------------+-------------------------+-------------+----------------+----------------+----------------+--------------------+--------------------+--------------------+-----------------+-----------------+-----------+----------------+-------------------+-------+--------------+------------------+----------------+----------------+--------------+--------------------------+---------------------------+---------------------+---------------------+---------------------------------+----------------------------+---------------------------+------------------------------------+---------------+---------------+--------+--------+-----------+--------------+------------+----------------+----------+----------------+--------------------+--------------------+--------------------+-----------+----+-----+----+
# |transaction_id   |procedure_id|trans_group_id|trans_group_ar|trans_group_en|procedure_name_ar         |procedure_name_en        |instance_date|property_type_id|property_type_ar|property_type_en|property_sub_type_id|property_sub_type_ar|property_sub_type_en|property_usage_ar|property_usage_en|reg_type_id|reg_type_ar     |reg_type_en        |area_id|area_name_ar  |area_name_en      |building_name_ar|building_name_en|project_number|project_name_ar           |project_name_en            |master_project_en    |master_project_ar    |nearest_landmark_ar              |nearest_landmark_en         |nearest_metro_ar           |nearest_metro_en                    |nearest_mall_ar|nearest_mall_en|rooms_ar|rooms_en|has_parking|procedure_area|actual_worth|meter_sale_price|rent_value|meter_rent_price|no_of_parties_role_1|no_of_parties_role_2|no_of_parties_role_3|instance_ts|year|month|dow |
# +-----------------+------------+--------------+--------------+--------------+--------------------------+-------------------------+-------------+----------------+----------------+----------------+--------------------+--------------------+--------------------+-----------------+-----------------+-----------+----------------+-------------------+-------+--------------+------------------+----------------+----------------+--------------+--------------------------+---------------------------+---------------------+---------------------+---------------------------------+----------------------------+---------------------------+------------------------------------+---------------+---------------+--------+--------+-----------+--------------+------------+----------------+----------+----------------+--------------------+--------------------+--------------------+-----------+----+-----+----+
# |2-110-2012-1625  |110         |2             |رهون          |Mortgages     |تسجيل إيجارة تنتهى بالتملك|Lease to Own Registration|16-10-2012   |3               |وحدة            |Unit            |60                  |شقه سكنيه           |Flat                |سكني             |Residential      |1          |العقارات القائمة|Existing Properties|350    |الثنيه الخامسة|Al Thanyah Fifth  |مدينة تاور      |MADINA TOWER    |75            |برج المدينة               |MADINA TOWER               |Jumeirah Lakes Towers| ابراج بحيرات الجميرا|برج العرب                        |Burj Al Arab                |محطة مترو مارينا مول       |Marina Mall Metro Station           |مارينا مول     |Marina Mall    |غرفتين  |2 B/R   |1          |190.17        |1280000.0   |6730.82         |1280000.0 |6730.82         |2                   |2                   |4                   |NULL       |NULL|NULL |NULL|
# |2-110-2009-100024|110         |2             |رهون          |Mortgages     |تسجيل إيجارة تنتهى بالتملك|Lease to Own Registration|02-02-2009   |4               |فيلا            |Villa           |4                   |فيلا                |Villa               |سكني             |Residential      |1          |العقارات القائمة|Existing Properties|434    |وادي الصفا 6  |Wadi Al Safa 6    |NULL            |NULL            |null          |NULL                      |NULL                       |Arabian Ranches - 1  |المرابع العربية - 1  |موتور سيتي                       |Motor City                  |NULL                       |NULL                                |NULL           |NULL           |غرفتين  |2 B/R   |0          |185.81        |768550.0    |4136.21         |768550.0  |4136.21         |2                   |2                   |2                   |NULL       |NULL|NULL |NULL|
# |2-32-2014-15     |32          |2             |رهون          |Mortgages     |تعديل إيجارة تنتهى بالتملك|Lease to Own Modify      |09-07-2014   |4               |فيلا            |Villa           |4                   |فيلا                |Villa               |سكني             |Residential      |1          |العقارات القائمة|Existing Properties|352    |الثنيه الرابعة|Al Thanayah Fourth|NULL            |NULL            |1045          |روعة الإمارات ? الينابيع 8|Emirates Living - Springs 8|Springs - 3          |الينابيع - 3         |أكاديمية المدينة الرياضية للسباحة|Sports City Swimming Academy|محطة مترو النخيل           |Nakheel Metro Station               |مارينا مول     |Marina Mall    |ثلاث غرف|3 B/R   |0          |269.79        |2520000.0   |9340.6          |2520000.0 |9340.6          |1                   |1                   |0                   |NULL       |NULL|NULL |NULL|
# |2-110-2013-688   |110         |2             |رهون          |Mortgages     |تسجيل إيجارة تنتهى بالتملك|Lease to Own Registration|04-04-2013   |4               |فيلا            |Villa           |4                   |فيلا                |Villa               |سكني             |Residential      |1          |العقارات القائمة|Existing Properties|352    |الثنيه الرابعة|Al Thanayah Fourth|NULL            |NULL            |1044          |روعة الإمارات ? الينابيع 7|Emirates Living - Springs 7|Springs - 3          |الينابيع - 3         |أكاديمية المدينة الرياضية للسباحة|Sports City Swimming Academy|محطة مترو النخيل           |Nakheel Metro Station               |مارينا مول     |Marina Mall    |ثلاث غرف|3 B/R   |0          |237.99        |2144000.0   |9008.78         |2144000.0 |9008.78         |4                   |2                   |2                   |NULL       |NULL|NULL |NULL|
# |2-110-2010-2729  |110         |2             |رهون          |Mortgages     |تسجيل إيجارة تنتهى بالتملك|Lease to Own Registration|28-10-2010   |3               |وحدة            |Unit            |60                  |شقه سكنيه           |Flat                |سكني             |Residential      |1          |العقارات القائمة|Existing Properties|390    |برج خليفة     |Burj Khalifa      |برج خليفة       |Burj Khalifa    |1462          |أبراج برج خليفة           |BURJ KHALIFA TOWERS        |DownTown Dubai       |داون تاون دبي        |برج خليفة                        |Burj Khalifa                |محطة مترو بوج خليفة دبي مول|Buj Khalifa Dubai Mall Metro Station|مول دبي        |Dubai Mall     |غرفتين  |2 B/R   |1          |175.4         |3378122.0   |19259.53        |3378122.0 |19259.53        |2                   |2                   |2                   |NULL       |NULL|NULL |NULL|
# +-----------------+------------+--------------+--------------+--------------+--------------------------+-------------------------+-------------+----------------+----------------+----------------+--------------------+--------------------+--------------------+-----------------+-----------------+-----------+----------------+-------------------+-------+--------------+------------------+----------------+----------------+--------------+--------------------------+---------------------------+---------------------+---------------------+---------------------------------+----------------------------+---------------------------+------------------------------------+---------------+---------------+--------+--------+-----------+--------------+------------+----------------+----------+----------------+--------------------+--------------------+--------------------+-----------+----+-----+----+
# only showing top 5 rows
#
# Partitions: 200

# %%
df.select("instance_date").show(5, truncate=False)
# Out:
# +-------------+
# |instance_date|
# +-------------+
# |14-11-2013   |
# |27-01-2020   |
# |10-09-2014   |
# |01-06-2020   |
# |09-11-2016   |
# +-------------+
# only showing top 5 rows

# %%
# !ls -lh /content/drive/MyDrive/dld_transactions/cleaned_parquet
# Out:
# total 6.8M
# -rw------- 1 root root 34K Jan 28 11:26 part-00000-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00001-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00002-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00003-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00004-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00005-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00006-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00007-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00008-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00009-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00010-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00011-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00012-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00013-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00014-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00015-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00016-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00017-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00018-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00019-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00020-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00021-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00022-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00023-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00024-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00025-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00026-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00027-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00028-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00029-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00030-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00031-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00032-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00033-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00034-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00035-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00036-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00037-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00038-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00039-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00040-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00041-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00042-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00043-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00044-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00045-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00046-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00047-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00048-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00049-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00050-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00051-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00052-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00053-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00054-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00055-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00056-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 36K Jan 28 11:26 part-00057-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00058-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00059-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 36K Jan 28 11:26 part-00060-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00061-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00062-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00063-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00064-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00065-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00066-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00067-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00068-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00069-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00070-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00071-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00072-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 36K Jan 28 11:26 part-00073-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00074-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00075-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00076-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00077-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00078-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00079-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00080-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00081-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00082-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00083-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00084-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00085-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00086-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00087-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00088-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00089-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00090-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00091-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 36K Jan 28 11:26 part-00092-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00093-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00094-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00095-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00096-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00097-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00098-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00099-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00100-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00101-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00102-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00103-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00104-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00105-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00106-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00107-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:26 part-00108-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:26 part-00109-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 36K Jan 28 11:27 part-00110-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00111-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00112-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00113-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00114-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00115-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00116-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 36K Jan 28 11:27 part-00117-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00118-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00119-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00120-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00121-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00122-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00123-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00124-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00125-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00126-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00127-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00128-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00129-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 36K Jan 28 11:27 part-00130-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00131-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00132-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00133-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00134-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00135-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00136-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00137-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00138-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00139-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00140-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00141-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00142-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00143-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00144-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00145-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00146-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00147-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00148-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00149-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00150-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00151-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00152-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 36K Jan 28 11:27 part-00153-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00154-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00155-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00156-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00157-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00158-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00159-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00160-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00161-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00162-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00163-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00164-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00165-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00166-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00167-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00168-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00169-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00170-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00171-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00172-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00173-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00174-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00175-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00176-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00177-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00178-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00179-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00180-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00181-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00182-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00183-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00184-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00185-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00186-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00187-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00188-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00189-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00190-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00191-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00192-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00193-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00194-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00195-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00196-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00197-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 34K Jan 28 11:27 part-00198-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root 35K Jan 28 11:27 part-00199-6d0dc871-b810-4b46-bcea-9a48fda3725a-c000.snappy.parquet
# -rw------- 1 root root   0 Jan 28 11:27 _SUCCESS
